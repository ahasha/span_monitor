# %%
from main import get_span_response
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
span_bearer_token = os.getenv("SPAN_API_KEY")
span_ip = os.getenv("SPAN_IP")

url = f"http://{span_ip}/api/v1/panel"
headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {span_bearer_token}"
}

# %%
response = get_span_response(url, headers=headers)

# %%
response.json()
# Out:
# {'mainRelayState': 'CLOSED',
#  'mainMeterEnergy': {'producedEnergyWh': 0.07011649291962385,
#   'consumedEnergyWh': 3594794.0},
#  'instantGridPowerW': 1988.2196044921875,
#  'feedthroughPowerW': 48.66798646003008,
#  'feedthroughEnergy': {'producedEnergyWh': 3572078.3206687244,
#   'consumedEnergyWh': 3590240.169222055},
#  'gridSampleStartMs': 2478634835,
#  'gridSampleEndMs': 2478634861,
#  'dsmGridState': 'DSM_GRID_UP',
#  'dsmState': 'DSM_ON_GRID',
#  'currentRunConfig': 'PANEL_ON_GRID',
#  'branches': [{'id': 1,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.6007099151611328,
#    'importedActiveEnergyWh': 578.5482788085938,
#    'exportedActiveEnergyWh': 59.35987854003906,
#    'measureStartTsMs': 2478634256,
#    'measureDurationMs': 39,
#    'isMeasureValid': True},
#   {'id': 2,
#    'relayState': 'CLOSED',
#    'instantPowerW': -1.6613520383834839,
#    'importedActiveEnergyWh': 0.048129837960004807,
#    'exportedActiveEnergyWh': 403998.28125,
#    'measureStartTsMs': 2478634256,
#    'measureDurationMs': 39,
#    'isMeasureValid': True},
#   {'id': 3,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.07782123237848282,
#    'importedActiveEnergyWh': 225.2183837890625,
#    'exportedActiveEnergyWh': 687.6297607421875,
#    'measureStartTsMs': 2478634295,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 4,
#    'relayState': 'CLOSED',
#    'instantPowerW': -2.69838547706604,
#    'importedActiveEnergyWh': 93.25775909423828,
#    'exportedActiveEnergyWh': 404027.34375,
#    'measureStartTsMs': 2478634295,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 5,
#    'relayState': 'CLOSED',
#    'instantPowerW': -698.6405029296875,
#    'importedActiveEnergyWh': 82.20487213134766,
#    'exportedActiveEnergyWh': 388010.5625,
#    'measureStartTsMs': 2478634318,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 6,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.5377534627914429,
#    'importedActiveEnergyWh': 848.74072265625,
#    'exportedActiveEnergyWh': 304044.1875,
#    'measureStartTsMs': 2478634318,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 7,
#    'relayState': 'CLOSED',
#    'instantPowerW': -699.7833862304688,
#    'importedActiveEnergyWh': 0.05932018160820007,
#    'exportedActiveEnergyWh': 388018.25,
#    'measureStartTsMs': 2478634341,
#    'measureDurationMs': 25,
#    'isMeasureValid': True},
#   {'id': 8,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.14952169358730316,
#    'importedActiveEnergyWh': 469.899169921875,
#    'exportedActiveEnergyWh': 303404.6875,
#    'measureStartTsMs': 2478634341,
#    'measureDurationMs': 25,
#    'isMeasureValid': True},
#   {'id': 9,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.6435553431510925,
#    'importedActiveEnergyWh': 992.7730712890625,
#    'exportedActiveEnergyWh': 62343.0390625,
#    'measureStartTsMs': 2478634366,
#    'measureDurationMs': 29,
#    'isMeasureValid': True},
#   {'id': 10,
#    'relayState': 'CLOSED',
#    'instantPowerW': -2.1562600135803223,
#    'importedActiveEnergyWh': 135.10345458984375,
#    'exportedActiveEnergyWh': 5473.4423828125,
#    'measureStartTsMs': 2478634366,
#    'measureDurationMs': 29,
#    'isMeasureValid': True},
#   {'id': 11,
#    'relayState': 'CLOSED',
#    'instantPowerW': -2.2008543014526367,
#    'importedActiveEnergyWh': 3.3466477394104004,
#    'exportedActiveEnergyWh': 69927.671875,
#    'measureStartTsMs': 2478634395,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 12,
#    'relayState': 'CLOSED',
#    'instantPowerW': -14.507975578308105,
#    'importedActiveEnergyWh': 77.12397003173828,
#    'exportedActiveEnergyWh': 17630.265625,
#    'measureStartTsMs': 2478634395,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 13,
#    'relayState': 'CLOSED',
#    'instantPowerW': -1.086874008178711,
#    'importedActiveEnergyWh': 0.21365901827812195,
#    'exportedActiveEnergyWh': 96227.5234375,
#    'measureStartTsMs': 2478634418,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 14,
#    'relayState': 'CLOSED',
#    'instantPowerW': -106.8468017578125,
#    'importedActiveEnergyWh': 0.9758262038230896,
#    'exportedActiveEnergyWh': 223745.421875,
#    'measureStartTsMs': 2478634418,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 15,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.23433808982372284,
#    'importedActiveEnergyWh': 102.16390991210938,
#    'exportedActiveEnergyWh': 74641.078125,
#    'measureStartTsMs': 2478634441,
#    'measureDurationMs': 22,
#    'isMeasureValid': True},
#   {'id': 16,
#    'relayState': 'CLOSED',
#    'instantPowerW': -3.3052163124084473,
#    'importedActiveEnergyWh': 0.019253643229603767,
#    'exportedActiveEnergyWh': 28116.51953125,
#    'measureStartTsMs': 2478634441,
#    'measureDurationMs': 22,
#    'isMeasureValid': True},
#   {'id': 17,
#    'relayState': 'CLOSED',
#    'instantPowerW': -6.996915340423584,
#    'importedActiveEnergyWh': 31.320079803466797,
#    'exportedActiveEnergyWh': 41023.63671875,
#    'measureStartTsMs': 2478634463,
#    'measureDurationMs': 28,
#    'isMeasureValid': True},
#   {'id': 18,
#    'relayState': 'CLOSED',
#    'instantPowerW': -91.9698257446289,
#    'importedActiveEnergyWh': 134.58218383789062,
#    'exportedActiveEnergyWh': 91087.734375,
#    'measureStartTsMs': 2478634463,
#    'measureDurationMs': 28,
#    'isMeasureValid': True},
#   {'id': 19,
#    'relayState': 'CLOSED',
#    'instantPowerW': -2.6109459400177,
#    'importedActiveEnergyWh': 0.04561462625861168,
#    'exportedActiveEnergyWh': 4269.65234375,
#    'measureStartTsMs': 2478634491,
#    'measureDurationMs': 26,
#    'isMeasureValid': True},
#   {'id': 20,
#    'relayState': 'CLOSED',
#    'instantPowerW': -91.14614868164062,
#    'importedActiveEnergyWh': 0.08069956302642822,
#    'exportedActiveEnergyWh': 125723.140625,
#    'measureStartTsMs': 2478634491,
#    'measureDurationMs': 26,
#    'isMeasureValid': True},
#   {'id': 21,
#    'relayState': 'CLOSED',
#    'instantPowerW': -10.490126609802246,
#    'importedActiveEnergyWh': 6.335050582885742,
#    'exportedActiveEnergyWh': 8228.7353515625,
#    'measureStartTsMs': 2478634517,
#    'measureDurationMs': 22,
#    'isMeasureValid': True},
#   {'id': 22,
#    'relayState': 'CLOSED',
#    'instantPowerW': 0.818434476852417,
#    'importedActiveEnergyWh': 194.44586181640625,
#    'exportedActiveEnergyWh': 7892.91796875,
#    'measureStartTsMs': 2478634517,
#    'measureDurationMs': 22,
#    'isMeasureValid': True},
#   {'id': 23,
#    'relayState': 'CLOSED',
#    'instantPowerW': -10.16922378540039,
#    'importedActiveEnergyWh': 146.18240356445312,
#    'exportedActiveEnergyWh': 16933.087890625,
#    'measureStartTsMs': 2478634539,
#    'measureDurationMs': 24,
#    'isMeasureValid': True},
#   {'id': 24,
#    'relayState': 'CLOSED',
#    'instantPowerW': -74.5579833984375,
#    'importedActiveEnergyWh': 56.06553649902344,
#    'exportedActiveEnergyWh': 107626.09375,
#    'measureStartTsMs': 2478634539,
#    'measureDurationMs': 24,
#    'isMeasureValid': True},
#   {'id': 25,
#    'relayState': 'CLOSED',
#    'instantPowerW': -64.62834167480469,
#    'importedActiveEnergyWh': 0.029724303632974625,
#    'exportedActiveEnergyWh': 84982.3359375,
#    'measureStartTsMs': 2478634563,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 26,
#    'relayState': 'CLOSED',
#    'instantPowerW': -13.099324226379395,
#    'importedActiveEnergyWh': 0.060034383088350296,
#    'exportedActiveEnergyWh': 25596.70703125,
#    'measureStartTsMs': 2478634563,
#    'measureDurationMs': 23,
#    'isMeasureValid': True},
#   {'id': 27,
#    'relayState': 'CLOSED',
#    'instantPowerW': -7.787369251251221,
#    'importedActiveEnergyWh': 29.784873962402344,
#    'exportedActiveEnergyWh': 213205.15625,
#    'measureStartTsMs': 2478634586,
#    'measureDurationMs': 27,
#    'isMeasureValid': True},
#   {'id': 28,
#    'relayState': 'CLOSED',
#    'instantPowerW': -31.844621658325195,
#    'importedActiveEnergyWh': 78.47566223144531,
#    'exportedActiveEnergyWh': 58859.16015625,
#    'measureStartTsMs': 2478634586,
#    'measureDurationMs': 27,
#    'isMeasureValid': True},
#   {'id': 29,
#    'relayState': 'CLOSED',
#    'instantPowerW': -1.6709704399108887,
#    'importedActiveEnergyWh': 0.05000343918800354,
#    'exportedActiveEnergyWh': 5065.818359375,
#    'measureStartTsMs': 2478634613,
#    'measureDurationMs': 26,
#    'isMeasureValid': True},
#   {'id': 30,
#    'relayState': 'CLOSED',
#    'instantPowerW': -1.8554679155349731,
#    'importedActiveEnergyWh': 7.3838043212890625,
#    'exportedActiveEnergyWh': 7997.8720703125,
#    'measureStartTsMs': 2478634613,
#    'measureDurationMs': 26,
#    'isMeasureValid': True},
#   {'id': 31,
#    'relayState': 'CLOSED',
#    'instantPowerW': -1.904434084892273,
#    'importedActiveEnergyWh': 73.78146362304688,
#    'exportedActiveEnergyWh': 3137.111572265625,
#    'measureStartTsMs': 2478634639,
#    'measureDurationMs': 22,
#    'isMeasureValid': True},
#   {'id': 32,
#    'relayState': 'CLOSED',
#    'instantPowerW': 1.0055551528930664,
#    'importedActiveEnergyWh': 185.5113525390625,
#    'exportedActiveEnergyWh': 93.9663314819336,
#    'measureStartTsMs': 2478634639,
#    'measureDurationMs': 22,
#    'isMeasureValid': True}]}
